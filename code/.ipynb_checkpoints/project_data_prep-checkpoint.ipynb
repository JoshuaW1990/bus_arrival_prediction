# %% [markdown]
# # bus arrival time prediction

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Test two different types of the data format

# %% [markdown]
# ### old historical data (2014)

# %% [markdown]
# The address of the data source: http://web.mta.info/developers/MTA-Bus-Time-historical-data.html

# %%
df = pd.read_csv('../data/MTA-Bus-Time_.2014-08-01.txt', delimiter='\t')

# %%
df.head(3)
# Out:
#     latitude  longitude        time_received  vehicle_id  distance_along_trip  \
# 0  40.668602 -73.986697  2014-08-01 04:00:01         469          4135.347107
# 1  40.713702 -73.979670  2014-08-01 04:00:01        3928          3974.805808
# 2  40.748222 -73.984180  2014-08-01 04:00:01        5854          1903.757563
#
#    inferred_direction_id  inferred_phase inferred_route_id  \
# 0                    1.0     IN_PROGRESS      MTA NYCT_B63
# 1                    0.0  LAYOVER_DURING      MTA NYCT_M22
# 2                    0.0     IN_PROGRESS     MTA NYCT_M34+
#
#                          inferred_trip_id  next_scheduled_stop_distance  \
# 0   MTA NYCT_JG_C4-Weekday-141500_B63_123                      2.631838
# 1   MTA NYCT_MQ_C4-Weekday-141000_M21_208                    129.330899
# 2  MTA NYCT_MQ_C4-Weekday-142800_SBS34_30                    319.658775
#
#   next_scheduled_stop_id
# 0             MTA_305423
# 1             MTA_903025
# 2             MTA_401824

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5160905 entries, 0 to 5160904
# Data columns (total 11 columns):
# latitude                        float64
# longitude                       float64
# time_received                   object
# vehicle_id                      int64
# distance_along_trip             float64
# inferred_direction_id           float64
# inferred_phase                  object
# inferred_route_id               object
# inferred_trip_id                object
# next_scheduled_stop_distance    float64
# next_scheduled_stop_id          object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 433.1+ MB

# %%
test = df.loc[df.inferred_trip_id=='MTA NYCT_MQ_C4-Weekday-141000_M21_208']

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 1 to 5153037
# Data columns (total 11 columns):
# latitude                        57 non-null float64
# longitude                       57 non-null float64
# time_received                   57 non-null object
# vehicle_id                      57 non-null int64
# distance_along_trip             57 non-null float64
# inferred_direction_id           57 non-null float64
# inferred_phase                  57 non-null object
# inferred_route_id               57 non-null object
# inferred_trip_id                57 non-null object
# next_scheduled_stop_distance    57 non-null float64
# next_scheduled_stop_id          57 non-null object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 5.3+ KB

# %%
test_layover = test[test.inferred_phase!='LAYOVER_DURING']

# %%
test_layover
# Out:
#           latitude  longitude        time_received  vehicle_id  \
# 1636     40.713684 -73.978750  2014-08-01 04:01:05        3928
# 5105162  40.714792 -74.016049  2014-08-02 03:27:10        3927
# 5106131  40.714831 -74.016126  2014-08-02 03:27:42        3927
# 5107068  40.714831 -74.016126  2014-08-02 03:28:13        3927
# 5108032  40.714831 -74.016126  2014-08-02 03:28:45        3927
# 5113753  40.715751 -74.015691  2014-08-02 03:31:55        3927
# 5114693  40.716828 -74.014524  2014-08-02 03:32:26        3927
# 5115666  40.716677 -74.013884  2014-08-02 03:32:58        3927
# 5116626  40.716654 -74.013835  2014-08-02 03:33:30        3927
MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5134961      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5135830      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5136703      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5137602      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5138489      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5139351      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5140229      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5141129      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5141953      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5142810      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5143699      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5144576      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5145416      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5146261      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5147090      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5147961      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5148789      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5149652      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5150513      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5151367      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5152202      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
# 5153037      MTA NYCT_M22  MTA NYCT_MQ_C4-Weekday-141000_M21_208
#
#          next_scheduled_stop_distance next_scheduled_stop_id
# 1636                       129.330899             MTA_903025
# 5105162                    390.945053             MTA_803100
# 5106131                    382.059938             MTA_803100
# 5107068                    382.059938             MTA_803100
# 5108032                    393.166332             MTA_803100
# 5113753                    268.774724             MTA_803100
# 5114693                    268.774724             MTA_803100
# 5115666                     33.319181             MTA_803100
# 5116626                     31.097902             MTA_803100
# 5117554                     37.724145             MTA_803147
# 5118543                     37.724145             MTA_803147
# 5119487                      2.219067             MTA_803147
# 5120430                    307.835209             MTA_803101
# 5121351                    252.067961             MTA_803101
# 5122272                    122.687946             MTA_803101
# 5123183                      4.461380             MTA_803101
# 5124088                    364.482389             MTA_402082
# 5125019                    364.482389             MTA_402082
# 5125947                    104.455319             MTA_402082
# 5126854                     57.783793             MTA_402082
# 5127746                    127.888439             MTA_404101
# 5128615                    246.525294             MTA_402085
# 5129534                    241.280075             MTA_402085
# 5130454                    104.904380             MTA_402085
# 5131343                    108.022714             MTA_401670
# 5132270                    108.022714             MTA_401670
# 5133183                     95.542827             MTA_402088
# 5134090                     95.542827             MTA_402088
# 5134961                      5.307935             MTA_402088
# 5135830                    191.998300             MTA_402090
# 5136703                    191.998300             MTA_402090
# 5137602                     35.264994             MTA_402090
# 5138489                    147.213608             MTA_402091
# 5139351                     71.170384             MTA_402092
# 5140229                     47.446922             MTA_402092
# 5141129                      0.000000             MTA_402092
# 5141953                     88.944834             MTA_402093
# 5142810                     19.765519             MTA_402093
# 5143699                     19.765519             MTA_402093
# 5144576                      0.000000             MTA_402093
# 5145416                     63.270019             MTA_402094
# 5146261                     18.981006             MTA_402094
# 5147090                      6.497028             MTA_402095
# 5147961                     70.324380             MTA_402096
# 5148789                     34.975943             MTA_402097
# 5149652                    108.691796             MTA_404922
# 5150513                    108.691796             MTA_404922
# 5151367                    132.564171             MTA_903025
# 5152202                    132.564171             MTA_903025
# 5153037                     32.332725             MTA_903025

# %% [markdown]
# #### Analysis for the old data (2014)
#
# The data record the location of the vehicle at different time point in the route with position in detail. However, it does'nt provide the specific time point when the bus arrive the stop.
#
# I used to think the layover_during progress represents the time spot for arriving at a stop. But I'm wrong. The actual meaning of the LAYOVERD_DURING is the waiting state at the start and the terminal stop in a route. It is not very critical for our data.
#
#
# - It is possible to be improved by the GTFS schedule data

# %% [markdown]
# ### new historical data with real time data

# %% [markdown]
# The address of the data source:
# - historical data: http://data.mytransit.nyc/bus_time/
# - real time data: http://bustime.mta.info/wiki/Developers/Index

# %% [markdown]
# #### new historical data

# %%
df =
